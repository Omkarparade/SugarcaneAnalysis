# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df=pd.read_csv('List of Countries by Sugarcane Production.csv')

# %%
df.head(5)
# Out:
#    Unnamed: 0   Country      Continent Production (Tons)  \
# 0           0    Brazil  South America       768.678.382
# 1           1     India           Asia       348.448.000
# 2           2     China           Asia       123.059.739
# 3           3  Thailand           Asia        87.468.496
# 4           4  Pakistan           Asia        65.450.704
#
#   Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                  3.668,531        10.226.205             75.167,5
# 1                     260721         4.950.000             70.393,5
# 2                      88287         1.675.215             73.459,1
# 3                  1.264,303         1.336.575             65.442,2
# 4                     324219         1.130.820               57.879

# %% [markdown]
# ## DATA CLEANING

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                    0
# Country                       0
# Continent                     0
# Production (Tons)             0
# Production per Person (Kg)    0
# Acreage (Hectare)             1
# Yield (Kg / Hectare)          1
# dtype: int64

# %%
df['Production (Tons)']=df['Production (Tons)'].str.replace('.','')
df['Production per Person (Kg)']=df['Production per Person (Kg)'].str.replace('.','').str.replace(',','')
df['Acreage (Hectare)']=df['Acreage (Hectare)'].str.replace('.','')
df['Yield (Kg / Hectare)']=df['Yield (Kg / Hectare)'].str.replace('.','').str.replace(',','')

# %%
df
# Out:
#      Unnamed: 0    Country      Continent Production (Tons)  \
# 0             0     Brazil  South America         768678382
# 1             1      India           Asia         348448000
# 2             2      China           Asia         123059739
# 3             3   Thailand           Asia          87468496
# 4             4   Pakistan           Asia          65450704
# ..          ...        ...            ...               ...
# 98           98    Lebanon           Asia                97
# 99           99   Djibouti         Africa                53
# 100         100  Singapore           Asia                50
# 101         101      Samoa        Oceania                12
# 102         102      Syria           Asia                 1
#
#     Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                      3668531          10226205               751675
# 1                       260721           4950000               703935
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                    0
# Country                       0
# Continent                     0
# Production (Tons)             0
# Production per Person (Kg)    0
# Acreage (Hectare)             1
# Yield (Kg / Hectare)          1
# dtype: int64

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df.head(5)
# Out:
#     Country      Continent Production (Tons) Production per Person (Kg)  \
# 0    Brazil  South America         768678382                    3668531
# 1     India           Asia         348448000                     260721
# 2     China           Asia         123059739                      88287
# 3  Thailand           Asia          87468496                    1264303
# 4  Pakistan           Asia          65450704                     324219
#
#   Acreage (Hectare) Yield (Kg / Hectare)
# 0          10226205               751675
# 1           4950000               703935
# 2           1675215               734591
# 3           1336575               654422
# 4           1130820                57879

# %%
df.rename(columns={'Production (Tons)':'Production(Tons)'},inplace=True)
df.rename(columns={'Production per Person (Kg)':'ProductionperPerson(Kg)'},inplace=True)
df.rename(columns={'Acreage (Hectare)':'Acreage (Hectare)'},inplace=True)
df.rename(columns={'Yield (Kg / Hectare)':'Yield (Kg / Hectare)'},inplace=True)

# %%
df.head()
# Out:
#     Country      Continent Production(Tons) ProductionperPerson(Kg)  \
# 0    Brazil  South America        768678382                 3668531
# 1     India           Asia        348448000                  260721
# 2     China           Asia        123059739                   88287
# 3  Thailand           Asia         87468496                 1264303
# 4  Pakistan           Asia         65450704                  324219
#
#   Acreage (Hectare) Yield (Kg / Hectare)
# 0          10226205               751675
# 1           4950000               703935
# 2           1675215               734591
# 3           1336575               654422
# 4           1130820                57879

# %%
df.isnull().sum()
# Out:
# Country                    0
# Continent                  0
# Production(Tons)           0
# ProductionperPerson(Kg)    0
# Acreage (Hectare)          1
# Yield (Kg / Hectare)       1
# dtype: int64

# %%
df.dropna().reset_index()
# Out:
#      index    Country      Continent Production(Tons) ProductionperPerson(Kg)  \
# 0        0     Brazil  South America        768678382                 3668531
# 1        1      India           Asia        348448000                  260721
# 2        2      China           Asia        123059739                   88287
# 3        3   Thailand           Asia         87468496                 1264303
# 4        4   Pakistan           Asia         65450704                  324219
# ..     ...        ...            ...              ...                     ...
# 97      97      Spain         Europe              394                       8
# 98      98    Lebanon           Asia               97                      16
# 99     100  Singapore           Asia               50                       9
# 100    101      Samoa        Oceania               12                       6
# 101    102      Syria           Asia                1                       0
#
# ...

# %%
df=df.dropna().reset_index().drop('index',axis=1)

# %%
df.isnull().sum()
# Out:
# Country                    0
# Continent                  0
# Production(Tons)           0
# ProductionperPerson(Kg)    0
# Acreage (Hectare)          0
# Yield (Kg / Hectare)       0
# dtype: int64

# %%
df.nunique()
# Out:
# Country                    102
# Continent                    6
# Production(Tons)           102
# ProductionperPerson(Kg)    101
# Acreage (Hectare)          101
# Yield (Kg / Hectare)       102
# dtype: int64

# %%
df.dtypes
# Out:
# Country                    object
# Continent                  object
# Production(Tons)           object
# ProductionperPerson(Kg)    object
# Acreage (Hectare)          object
# Yield (Kg / Hectare)       object
# dtype: object

# %%
df['Production(Tons)']=df['Production(Tons)'].astype(float)
df['ProductionperPerson(Kg)']=df['ProductionperPerson(Kg)'].astype(float)
df['Acreage (Hectare)']=df['Acreage (Hectare)'].astype(float)
df['Yield (Kg / Hectare)']=df['Yield (Kg / Hectare)'].astype(float)

# %%
df.dtypes
# Out:
# Country                     object
# Continent                   object
# Production(Tons)           float64
# ProductionperPerson(Kg)    float64
# Acreage (Hectare)          float64
# Yield (Kg / Hectare)       float64
# dtype: object

# %% [markdown]
# ## univarient analysis

# %% [markdown]
# ## How many countries produce sugarcane from each continent

# %%
df['Continent'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Continent'>

# %% [markdown]
# ## Outlier checking

# %%
df.describe()
# Out:
#        Production(Tons)  ProductionperPerson(Kg)  Acreage (Hectare)  \
# count      1.020000e+02             1.020000e+02       1.020000e+02
# mean       1.850372e+07             4.124805e+05       2.498981e+05
# std        8.419149e+07             8.669140e+05       1.137003e+06
# min        1.000000e+00             0.000000e+00       0.000000e+00
# 25%        6.251875e+04             1.075225e+04       1.104000e+03
# 50%        1.440044e+06             8.135850e+04       1.655800e+04
# 75%        6.426824e+06             2.828128e+05       8.047400e+04
# max        7.686784e+08             4.816299e+06       1.022620e+07
#
#        Yield (Kg / Hectare)
# count          1.020000e+02
# mean           5.018502e+05
# std            3.169530e+05
# min            1.000000e+01
# 25%            2.487505e+05
# 50%            5.102500e+05
# 75%            7.198920e+05
# max            1.290493e+06

# %% [markdown]
# ## Boxplot

# %%
plt.figure(figsize=(12,8))
plt.subplot(2,2,1)
sns.boxplot(df['Production(Tons)'])
plt.title('Production(Tons)')
plt.subplot(2,2,2)
sns.boxplot(df['ProductionperPerson(Kg)'])
plt.title('ProductionperPerson(Kg)')
plt.subplot(2,2,3)
sns.boxplot(df['Acreage (Hectare)'])
plt.title('Acreage (Hectare)')
plt.subplot(2,2,4)
sns.boxplot(df['Yield (Kg / Hectare)'])
plt.title('Yield (Kg / Hectare)')
# Out:
# Text(0.5, 1.0, 'Yield (Kg / Hectare)')

# %% [markdown]
# ## distribution

# %%
plt.figure(figsize=(12,8))
plt.subplot(2,2,1)
sns.distplot(df['Production(Tons)'])
plt.title('Production(Tons)')
plt.subplot(2,2,2)
sns.distplot(df['ProductionperPerson(Kg)'])
plt.title('ProductionperPerson(Kg)')
plt.subplot(2,2,3)
sns.distplot(df['Acreage (Hectare)'])
plt.title('Acreage (Hectare)')
plt.subplot(2,2,4)
sns.distplot(df['Yield (Kg / Hectare)'])
plt.title('Yield (Kg / Hectare)')
# Out:
# C:\Users\OMKAR\AppData\Local\Temp\ipykernel_9200\1797648614.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Production(Tons)'])
# C:\Users\OMKAR\AppData\Local\Temp\ipykernel_9200\1797648614.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
df.corr(numeric_only=True)
# Out:
#                          Production(Tons)  ProductionperPerson(Kg)  \
# Production(Tons)                 1.000000                 0.352369
# ProductionperPerson(Kg)          0.352369                 1.000000
# Acreage (Hectare)                0.997550                 0.341974
# Yield (Kg / Hectare)             0.121125                 0.226719
#
#                          Acreage (Hectare)  Yield (Kg / Hectare)
# Production(Tons)                  0.997550              0.121125
# ProductionperPerson(Kg)           0.341974              0.226719
# Acreage (Hectare)                 1.000000              0.107826
# Yield (Kg / Hectare)              0.107826              1.000000

# %%
plt.figure(figsize=(12,8))
plt.subplot(2,2,1)
sns.violinplot(df['Production(Tons)'])
plt.title('Production(Tons)')
plt.subplot(2,2,2)
sns.violinplot(df['ProductionperPerson(Kg)'])
plt.title('ProductionperPerson(Kg)')
plt.subplot(2,2,3)
sns.violinplot(df['Acreage (Hectare)'])
plt.title('Acreage (Hectare)')
plt.subplot(2,2,4)
sns.violinplot(df['Yield (Kg / Hectare)'])
plt.title('Yield (Kg / Hectare)')
# Out:
# Text(0.5, 1.0, 'Yield (Kg / Hectare)')

# %% [markdown]
# ## Bivariante Analysis

# %%
df
# Out:
#        Country      Continent  Production(Tons)  ProductionperPerson(Kg)  \
# 0       Brazil  South America       768678382.0                3668531.0
# 1        India           Asia       348448000.0                 260721.0
# 2        China           Asia       123059739.0                  88287.0
# 3     Thailand           Asia        87468496.0                1264303.0
# 4     Pakistan           Asia        65450704.0                 324219.0
# ..         ...            ...               ...                      ...
# 97       Spain         Europe             394.0                      8.0
# 98     Lebanon           Asia              97.0                     16.0
# 99   Singapore           Asia              50.0                      9.0
# 100      Samoa        Oceania              12.0                      6.0
# 101      Syria           Asia               1.0                      0.0
#
#      Acreage (Hectare)  Yield (Kg / Hectare)
# 0           10226205.0              751675.0
# ...

# %%
df_new=df[['Country','Production(Tons)']].set_index('Country')

# %%
df_new.head()
# Out:
#           Production(Tons)
# Country
# Brazil         768678382.0
# India          348448000.0
# China          123059739.0
# Thailand        87468496.0
# Pakistan        65450704.0

# %%
df_new['Production(Tons)'].plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='Production(Tons)'>

# %% [markdown]
# form this pie chart we can notice that Brazil,India,China produce sugarcane about 65% of whole woeld

# %% [markdown]
# ## sugarcane production by countries in descending order

# %%
df[['Country','Production(Tons)']].set_index('Country').sort_values('Production(Tons)',ascending=False).head(20).plot(kind='bar')
# Out:
# <Axes: xlabel='Country'>

# %%
ax = sns.barplot(data = df.head(15),  x= "Country", y = "Production(Tons)",palette='Set2')
ax.set_xticklabels(ax.get_xticklabels(),rotation =90)
plt.show()
# Out:
# C:\Users\OMKAR\AppData\Local\Temp\ipykernel_9200\287023420.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data = df.head(15),  x= "Country", y = "Production(Tons)",palette='Set2')
# C:\Users\OMKAR\AppData\Local\Temp\ipykernel_9200\287023420.py:2: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(),rotation =90)

# %%
ax = sns.barplot(data = df.head(15),  x= "Country", y = "Acreage (Hectare)",palette='Set2')
ax.set_xticklabels(ax.get_xticklabels(),rotation =90)
plt.show()
# Out:
# C:\Users\OMKAR\AppData\Local\Temp\ipykernel_9200\2566429949.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data = df.head(15),  x= "Country", y = "Acreage (Hectare)",palette='Set2')
# C:\Users\OMKAR\AppData\Local\Temp\ipykernel_9200\2566429949.py:2: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(),rotation =90)

# %% [markdown]
# ## Acreage of the country in descending order

# %%
df_yeild=df.sort_values('Acreage (Hectare)',ascending=False).head(15)

# %%
ax=sns.barplot(data=df_yeild,y='Acreage (Hectare)',x='Country',palette='Set2')
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
plt.show()
# Out:
# C:\Users\OMKAR\AppData\Local\Temp\ipykernel_9200\2647312266.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.barplot(data=df_yeild,y='Acreage (Hectare)',x='Country',palette='Set2')
# C:\Users\OMKAR\AppData\Local\Temp\ipykernel_9200\2647312266.py:2: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(),rotation=90)

# %% [markdown]
# ## productionperperson of the country in descending order

# %%
df_production=df.sort_values('ProductionperPerson(Kg)',ascending=False).head(15)
ax=sns.barplot(data=df_production,y='ProductionperPerson(Kg)',x='Country',palette='Set2')
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
plt.show()
# Out:
# C:\Users\OMKAR\AppData\Local\Temp\ipykernel_9200\3486185717.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.barplot(data=df_production,y='ProductionperPerson(Kg)',x='Country',palette='Set2')
# C:\Users\OMKAR\AppData\Local\Temp\ipykernel_9200\3486185717.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(),rotation=90)

# %% [markdown]
# ## Heatmap showing correlation :It shows that Acreage is directly related to Production of Sugarcane

# %%
x=df.corr(numeric_only=True)

# %%
x
# Out:
#                          Production(Tons)  ProductionperPerson(Kg)  \
# Production(Tons)                 1.000000                 0.352369
# ProductionperPerson(Kg)          0.352369                 1.000000
# Acreage (Hectare)                0.997550                 0.341974
# Yield (Kg / Hectare)             0.121125                 0.226719
#
#                          Acreage (Hectare)  Yield (Kg / Hectare)
# Production(Tons)                  0.997550              0.121125
# ProductionperPerson(Kg)           0.341974              0.226719
# Acreage (Hectare)                 1.000000              0.107826
# Yield (Kg / Hectare)              0.107826              1.000000

# %%
sns.heatmap(x,annot=True,fmt='.2f')
# Out:
# <Axes: >

# %%
sns.scatterplot(data=df,x='Acreage (Hectare)',y='Production(Tons)',hue='Continent')
# Out:
# <Axes: xlabel='Acreage (Hectare)', ylabel='Production(Tons)'>

# %%
sns.scatterplot(data=df,x='Yield (Kg / Hectare)',y='Production(Tons)',hue='Continent')
# Out:
# <Axes: xlabel='Yield (Kg / Hectare)', ylabel='Production(Tons)'>

# %%
df.head()
# Out:
#     Country      Continent  Production(Tons)  ProductionperPerson(Kg)  \
# 0    Brazil  South America       768678382.0                3668531.0
# 1     India           Asia       348448000.0                 260721.0
# 2     China           Asia       123059739.0                  88287.0
# 3  Thailand           Asia        87468496.0                1264303.0
# 4  Pakistan           Asia        65450704.0                 324219.0
#
#    Acreage (Hectare)  Yield (Kg / Hectare)
# 0         10226205.0              751675.0
# 1          4950000.0              703935.0
# 2          1675215.0              734591.0
# 3          1336575.0              654422.0
# 4          1130820.0               57879.0

# %% [markdown]
# ## analysis for continent

# %%
df_continent=df.groupby('Continent').sum()

# %%
df_continent
# Out:
#                                                          Country  \
# Continent
# Africa         EgyptSouth AfricaKenyaSwazilandSudanZambiaMaur...
# Asia           IndiaChinaThailandPakistanIndonesiaPhilippines...
# Europe                                             PortugalSpain
# North America  MexicoGuatemalaUnited States of AmericaCubaEl ...
# Oceania                       AustraliaFijiPapua New GuineaSamoa
# South America  BrazilColombiaArgentinaPeruEcuadorBoliviaParag...
#
#                Production(Tons)  ProductionperPerson(Kg)  Acreage (Hectare)  \
# Continent
# Africa               89681472.0               10144110.0          1439089.0
# Asia                721930425.0                3120808.0         10608319.0
# Europe                   5823.0                    536.0               71.0
# North America       173995947.0               15420953.0          1581983.0
# Oceania              36177574.0                3158066.0           490909.0
# ...

# %%
df_continent.drop('Country',axis=1,inplace=True)

# %%
df_continent
# Out:
#                Production(Tons)  ProductionperPerson(Kg)  Acreage (Hectare)  \
# Continent
# Africa               89681472.0               10144110.0          1439089.0
# Asia                721930425.0                3120808.0         10608319.0
# Europe                   5823.0                    536.0               71.0
# North America       173995947.0               15420953.0          1581983.0
# Oceania              36177574.0                3158066.0           490909.0
# South America       865588126.0               10228540.0         11369236.0
#
#                Yield (Kg / Hectare)  number_of_countries
# Continent
# Africa                   20700454.0                   38
# Asia                     11197308.0                   25
# Europe                    1318709.0                    2
# North America             9581162.0                   22
# Oceania                   1624191.0                    4
# South America             6766896.0                   11

# %%
df_continent["number_of_countries"] = df.groupby("Continent")["Country"].count()

# %%
df_continent["Production(Tons)"].sort_values(ascending =  False).plot(kind = "bar")
# Out:
# <Axes: xlabel='Continent'>

# %% [markdown]
# ## Do number of countries in a Continent effects production of sugarcane?

# %%
continent_names = df_continent.index.to_list()
sns.lineplot(data = df_continent,x = "number_of_countries", y= "Production(Tons)" )
plt.xticks(df_continent["number_of_countries"], continent_names, rotation =90)
plt.show()

# %% [markdown]
# ## From lineplot we can analyse that Acreage affects the production of Sugarcane Not the Number of Countries

# %%
sns.lineplot(data = df_continent,x = "Acreage (Hectare)", y= "Production(Tons)" )
# Out:
# <Axes: xlabel='Acreage (Hectare)', ylabel='Production(Tons)'>
